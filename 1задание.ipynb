# %%
from settings import *

# %% [markdown]
# ## Литва

# %% [markdown]
# ## 1 задание

# %% [markdown]
# ### Графики в текущих ценах

# %%
plt.figure(figsize=(10, 10))
plt.plot(Y.index, Y, 'b', label='GDP')
plt.plot(I.index, I, 'r', label='Import')
plt.plot(C.index, C, 'y', label='Consumption')
plt.plot(J.index, J, 'm', label='GCF')
plt.plot(E.index, E, 'g', label='Export')
# plt.yscale('log')
plt.legend(loc='best', fontsize=15)
plt.show()

# %% [markdown]
# ### Графики в ценах 2015 года

# %%
plt.figure(figsize=(10, 10))
plt.plot(Y.index, Y / Y.loc[2015], 'b', label='GDP')
plt.plot(I.index, I / I.loc[2015], 'r', label='Import')
plt.plot(C.index, C / C.loc[2015], 'y', label='Consumption')
plt.plot(J.index, J / J.loc[2015], 'm', label='GCF')
plt.plot(E.index, E / E.loc[2015], 'g', label='Export')


plt.legend(loc='best', fontsize=15)
plt.show()
